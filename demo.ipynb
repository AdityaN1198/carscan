# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from util import label_img
import cv2
import os
from IPython.display import Image

# %%
data = []
images = []

for j in os.listdir('Assignment\Data Visualization\data'):
	data.append(r'Assignment\Data Visualization\data'+ '\\' + j )

for j in os.listdir('Assignment\Data Visualization\images'):
    images.append(r'Assignment\Data Visualization\images'+ '\\' + j)


for i in range(len(data)):
    filled_poly_img, line_poly_img = label_img(image_path= '{}'.format(images[i]),meta_data_json_path='{}'.format(data[i]),opacity =0.6)
    plt.imshow(cv2.cvtColor(filled_poly_img, cv2.COLOR_BGR2RGB))
    plt.show()
    plt.imshow(cv2.cvtColor(line_poly_img, cv2.COLOR_BGR2RGB))
    plt.show()
